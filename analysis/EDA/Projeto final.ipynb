# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import tree
import pandas_profiling
#import graphviz

# %% [markdown]
# ## Import da base
# Importando a base e fazendo split para o profile_report
#
# - com 20k elemntos aprox 1h30 para executar
# - com 200k elementos parei após 6h executando
# - update com 50k, porém com as 49 features já selecionadas pelo Fernando

# %%
base = pd.read_csv("../estaticos_49_features.csv", index_col = 0)

base_split = base

# %%
profile = base_split.profile_report(style={'full_width':True}, title='Pandas Profiling Report',check_recoded = False)
profile.to_file(output_file="output_49f.html")

# %% [markdown]
# ## Import Clientes
#
# Import and profile_report of clientes_1,2 and 3

# %%
clientes_1 = pd.read_csv("../estaticos_portfolio1.csv", index_col = 0)
clientes_2 = pd.read_csv("../clientes2_merge.csv", index_col = 0)
clientes_3 = pd.read_csv("../clientes3_merge.csv", index_col = 0)

# %%
profile_1 = clientes_1.profile_report(style={'full_width':True}, title='Pandas Profiling Report',check_recoded = False)
profile_1.to_file(output_file="clientes_1.html")
#clientes_2 = clientes_2.merge(base, on="id", how= 'left')

profile_2 = clientes_2.profile_report(style={'full_width':True}, title='Pandas Profiling Report',check_recoded = False)
profile_2.to_file(output_file="clientes_2.html")

profile_3 = clientes_3.profile_report(style={'full_width':True}, title='Pandas Profiling Report',check_recoded = False)
profile_3.to_file(output_file="clientes_3.html")

# %%
#clientes_3 = clientes_3.merge(base, on="id", how= 'left')

# %% [markdown]
# # Redução dimensionalidade Dataset
# After empiric best feature selectio, apply decision tree with 2 features with target

# %%
#cl_1_dmm = pd.get_dummies(clientes_1_d)
corr = cl_1_dmm.corr()
plt.figure(figsize=(12,10))
plt.imshow(corr, cmap='hot', interpolation='none')

# %%
#de_natureza_juridica
#de_nivel_atividade



tree_clf = tree.DecisionTreeClassifier()

tree_clf = tree_clf.fit(cl_1_dmm, axis=1), clientes_1.de_natureza_juridica)
# Out:
#   File "<ipython-input-20-d7e58d46d7ba>", line 8
#     tree_clf = tree_clf.fit(cl_1_dmm, axis=1), clientes_1.de_natureza_juridica)
#                                                                               ^
# SyntaxError: invalid syntax

# %%
base.fl_veiculo.value_counts()#[1]/base.fl_sa.value_counts()[0]

# %%
#de_ramo
#setor
#nm_divisao
#nm_segmento

# %%
# Out:
#      fl_matriz  idade_empresa_anos  fl_me  fl_sa  fl_epp  fl_mei  fl_ltda  \
# 0         True            0.646575  False  False   False    True    False
# 1        False            6.586301  False  False   False   False    False
# 2         True            8.010959  False  False   False    True    False
# 3         True           20.863014  False  False   False   False    False
# 4         True           18.726027  False  False   False   False    False
# ..         ...                 ...    ...    ...     ...     ...      ...
# 550       True           27.660274  False  False   False   False    False
# 551       True            1.597260  False  False   False    True    False
# 552       True           31.868493  False  False   False   False    False
# 553       True            0.969863  False  False   False    True    False
# 554       True            3.994521  False  False   False    True    False
#
#      fl_st_especial  fl_email  fl_telefone  ...  \
# ...
